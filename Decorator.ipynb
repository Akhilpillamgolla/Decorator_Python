# %% [markdown]
# ## Decorator
#  They help to make your code shorter and more `Pythonic`. </br>
#  We use @ to indicate that as decorator  </br>
#
# ![image.png](attachment:image.png)

# %%
def fun():
    return 'Hi'

# %%
fun()
# Out:
# 'Hi'

# %%
def hello(name = 'Akhil'):
    print('Hello fun()')
    
    def greet():
        return '\t Green fun() is inside hello fun'
    
    print(greet()) # if we dont mention this then it will not print this

# %%
hello()
# Out:
# Hello fun()
# 	 Green fun() is inside hello fun

# %%
# lets also add welcome fun to above : 
def hello(name = 'Akhil'):
    print('Hello fun()')
    
    def greet():
        return '\t Green fun()  inside hello fun'
    def welcome():
        return '\t Welcome Fun() inside hello fun'
    
    print(welcome())
    print(greet()) # if we dont mention this then it will not print this

# %%
hello()
# Out:
# Hello fun()
# 	 Welcome Fun() inside hello fun
# 	 Green fun()  inside hello fun

# %%
# if we try to execute welcome ,greet outside that function 
#we will get error

# welcome() 
# greet()    # uncomment to see error.
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[18], line 4
#       1 # if we try to execute welcome ,greet outside that function
#       2 #we will get error
# ----> 4 welcome()
#
# NameError: name 'welcome' is not defined

# %%
# Returning Functions
def hello(name = 'Akhil'):
    print('Hello fun()')
    
    def greet():
        return '\t Green fun()  inside hello fun'
    def welcome():
        return '\t Welcome Fun() inside hello fun'
    
    print('I am Returning Function')
    
    if name == 'Akhil':
        return greet()
    else :
        return welcome()

# %%
check = hello('Akhil')
# Out:
# Hello fun()
# I am inside Hello Function

# %%
def name():
    return 'Akhil'

# %% [markdown]
# Functions as Arguments

# %%
def hello():
    return 'Hi Akhil!'

# %%
def other(func): # passing function as argument.
    print('Other code would go here')
    print(func())

# %%
other(hello) # i am passing 1 function -> another function
# Out:
# Other code would go here
# Hi Akhil!

# %% [markdown]
# Decorator Example

# %%
def new_decorator(func):

    def wrap_func():
        print("Code would be here, before executing the func")

        func()

        print("Code here will execute after the func()")

    return wrap_func

# %%
def func_needs_decorator():
    print("This function is in need of a Decorator")

# %%
func_needs_decorator()
# This function is in need of a Decorator
# Out:
# This function is in need of a Decorator

# %%
# Reassign func_needs_decorator
func_needs_decorator = new_decorator(func_needs_decorator)

# %%
func_needs_decorator()
# Out:
# Code would be here, before executing the func
# This function is in need of a Decorator
# Code here will execute after the func()

# %% [markdown]
# A decorator simply wrapped the function and modified its behavior.

# %% [markdown]
# We can also write the above code using @

# %%
@new_decorator
def func_needs_decorator():
    print("This function is in need of a Decorator")

# %%
func_needs_decorator()
# Out:
# Code would be here, before executing the func
# This function is in need of a Decorator
# Code here will execute after the func()

# %%
# to disable decorator 
#@new_decorator
def func_needs_decorator():
    print("This function is in need of a Decorator")

# %%
func_needs_decorator()
# Out:
# This function is in need of a Decorator
